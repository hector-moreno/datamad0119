# %%
# imports
from dotenv import load_dotenv
import os
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# KEY
load_dotenv(dotenv_path='.env')
SECRET_KEY = os.getenv("KEY")

# %% [markdown]
# Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
#     Obtain the full list of forks created from the main lab repo via Github API.

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/datamad0119/forks')
results = response.json()
results
# Out:
# [{'id': 167147514,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNjcxNDc1MTQ=',
#   'name': 'datamad0119-1',
#   'full_name': 'RodMech/datamad0119-1',
#   'private': False,
#   'owner': {'login': 'RodMech',
#    'id': 33937164,
#    'node_id': 'MDQ6VXNlcjMzOTM3MTY0',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/33937164?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RodMech',
#    'html_url': 'https://github.com/RodMech',
#    'followers_url': 'https://api.github.com/users/RodMech/followers',
#    'following_url': 'https://api.github.com/users/RodMech/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/RodMech/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/RodMech/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/RodMech/subscriptions',
#    'organizations_url': 'https://api.github.com/users/RodMech/orgs',
#    'repos_url': 'https://api.github.com/users/RodMech/repos',
# ...

# %%
dfForks=pd.DataFrame(results)
dfForks
# Out:
#                                           archive_url  archived  \
# 0   https://api.github.com/repos/RodMech/datamad01...     False
# 1   https://api.github.com/repos/Almuglezsalcedo/d...     False
# 2   https://api.github.com/repos/leyremarazuela/da...     False
# 3   https://api.github.com/repos/pecatade/datamad0...     False
# 4   https://api.github.com/repos/NicoST1/datamad01...     False
# 5   https://api.github.com/repos/potacho/datamad01...     False
# 6   https://api.github.com/repos/LauraRepullo/data...     False
# 7   https://api.github.com/repos/carlosmd14/datama...     False
# 8   https://api.github.com/repos/Paulapr/datamad01...     False
# 9   https://api.github.com/repos/alejandroperela/d...     False
# 10  https://api.github.com/repos/LiviaCanet/datama...     False
# 11  https://api.github.com/repos/lmartinezruizit/d...     False
# 12  https://api.github.com/repos/hector-moreno/dat...     False
# 13  https://api.github.com/repos/alejandrofrank/da...     False
#
# ...

# %%
dfForks.full_name.value_counts()
# Out:
# carlosmd14/datamad0119           1
# Almuglezsalcedo/datamad0119      1
# alejandroperela/datamad0119      1
# lmartinezruizit/datamad0119-1    1
# alejandrofrank/datamad0119       1
# pecatade/datamad0119             1
# RodMech/datamad0119-1            1
# NicoST1/datamad0119              1
# hector-moreno/datamad0119        1
# Paulapr/datamad0119              1
# LauraRepullo/datamad0119         1
# potacho/datamad0119              1
# leyremarazuela/datamad0119       1
# LiviaCanet/datamad0119           1
# Name: full_name, dtype: int64

# %% [markdown]
# 2.
#
# Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
#     Hint: Each language should appear only once in your array.

# %%
languages = []
for result in results:
    for ff in result:
        if ff == 'language':
            languages.append(result[ff])

for i in languages:
    print(i)
# Out:
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook
# Jupyter Notebook

# %%
dfForks.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'downloads_url',
#        'events_url', 'fork', 'forks', 'forks_count', 'forks_url', 'full_name',
#        'git_commits_url', 'git_refs_url', 'git_tags_url', 'git_url',
#        'has_downloads', 'has_issues', 'has_pages', 'has_projects', 'has_wiki',
#        'homepage', 'hooks_url', 'html_url', 'id', 'issue_comment_url',
#        'issue_events_url', 'issues_url', 'keys_url', 'labels_url', 'language',
#        'languages_url', 'license', 'merges_url', 'milestones_url',
#        'mirror_url', 'name', 'node_id', 'notifications_url', 'open_issues',
#        'open_issues_count', 'owner', 'private', 'pulls_url', 'pushed_at',
#        'releases_url', 'size', 'ssh_url', 'stargazers_count', 'stargazers_url',
# ...

# %% [markdown]
# 3.
#
# Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %%
dfForks.language.value_counts()
# Out:
# Jupyter Notebook    14
# Name: language, dtype: int64
